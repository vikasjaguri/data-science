# %% [markdown]
# ## Importing Matplotlib

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
plt.show()

# %%
import numpy as np
x = np.linspace(0, 10, 100)
fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--');

# %%
x=np.linspace(0,5 ,11)
y=x

plt.plot(x,y,'c.-')
plt.xlabel('This is X axis')
plt.ylabel('This is Y axis')
plt.title('This is a graph')
# Out:
# Text(0.5, 1.0, 'This is a graph')

# %%
plt.plot(x+2,y+3,'g.-')
plt.xlim(-2,12)
plt.ylim(-3,4)
plt.xlabel('This is X axis')
plt.ylabel('This is Y axis')
plt.title('This is a graph')
# Out:
# Text(0.5, 1.0, 'This is a graph')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r+-')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Chart')
plt.xlim(3,12)
plt.ylim(4,10)
plt.show()

# %% [markdown]
# ## Figures

# %%
fig = plt.figure()

# %%
a=np.arange(0,10)
b=a**2

plt.plot(a,np.cos(a),'m+-')
plt.plot(b,np.cos(b),'g^-')
plt.xlabel('This is A axis')
plt.ylabel('This is B axis')
plt.title('graph')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r--')
plt.subplot(1,2,2)
plt.plot(y,x,'c^-')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.subplot(1,2,1)
plt.plot(a,b,'ro-')
plt.subplot(1,2,2)
plt.plot(b,a,'bs-')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig = plt.figure()
axes1= fig.add_axes([0,0,1,1])
axes2= fig.add_axes([0.2,0.5,0.2,0.2])

axes1.plot(x,y,'g*-')
axes1.plot(y,x+5,'c.-')
axes1.set_xlabel('set X label')
axes1.set_ylabel('set Y label')
axes1.set_title('Graph')

axes2.plot(x,y,'r--')
axes2.set_xlabel('set X label')
axes2.set_ylabel('set Y label')
axes2.set_title('Graph')
# Out:
# Text(0.5, 1.0, 'Graph')

# %%
import pandas as pd
data = [[90,91,89,89,91,96,98,92],
        [88,80,84,88,84,96,94,94],
        [74,72,71,76,73,70,70,75],
        [84,86,86,87,80,82,78,82],
        [74,80,74,88,87,78,52,84]]
df = pd.DataFrame(data , columns=["OOAD","Data Science","Statistics","Python","Flutter","ML","C#","Java"] ,
                index = ["Ajin","Ajish","Ashish","Anish","Abin"])
df
# Out:
#         OOAD  Data Science  Statistics  Python  Flutter  ML  C#  Java
# Ajin      90            91          89      89       91  96  98    92
# Ajish     88            80          84      88       84  96  94    94
# Ashish    74            72          71      76       73  70  70    75
# Anish     84            86          86      87       80  82  78    82
# Abin      74            80          74      88       87  78  52    84

# %%
fig , axes = plt.subplots(2,2, layout="constrained")

axes[0,0].plot(df.index,df.Python,'k--' , label='py')
axes[0,0].set_xlabel('X axis')
axes[0,0].set_ylabel('Y axis')
axes[0,0].set_title('Chart')
axes[0,0].legend()

axes[0,1].plot(df.index,df.ML,'g--' , label='ml')
axes[0,1].set_xlabel('X axis')
axes[0,1].set_ylabel('Y axis')
axes[0,1].set_title('Chart')
axes[0,1].legend()

axes[1,0].plot(df.index,df.OOAD,'c--' , label='ooad')
axes[1,0].set_xlabel('X axis')
axes[1,0].set_ylabel('Y axis')
axes[1,0].set_title('Chart')
axes[1,0].legend()

axes[1,1].plot(df.index,df.Java,'m--' , label='java')
axes[1,1].set_xlabel('X axis')
axes[1,1].set_ylabel('Y axis')
axes[1,1].set_title('Chart')
axes[1,1].legend()


fig.savefig("filename.png")

# %%
a=np.arange(10)
b=a**2
plt.scatter(a,b)

# %%
np.random.seed(3)
x=4+np.random.normal(0,2,24)
y=4+np.random.normal(0,2,len(x))
sizes=np.random.uniform(45,80,len(x))
colors=np.random.uniform(15,95,len(x))
fig , ax = plt.subplots()
ax.scatter(x , y , s=sizes , c=colors)
ax.set(xlim=(0,8) , ylim=(0,8))
plt.scatter(x,y,c=colors,s=sizes,alpha=0.7,cmap='magma',marker='s',edgecolors='red')
plt.colorbar()

# %%
x=np.random.rand(50)
y=np.random.rand(50)
colors=np.random.rand(50)
sizes=100*np.random.rand(50)
plt.scatter(x,y,c=colors,s=sizes,alpha=0.7,cmap='brg')
plt.colorbar()

# %%
x = [5, 7, 8,7, 2, 17, 2, 9, 4, 11, 12, 9, 6 ]
y = [99, 86, 87, 88, 100,86, 103, 87, 94, 78, 77, 85, 86]

bubble_sizes = [30, 80, 85, 86, 150, 200, 300, 87, 94, 78, 77, 85, 86]

fig, ax = plt.subplots(1, 4)
ax[1].scatter(x,y,c ="green")
ax[0].scatter(x,y, c= "pink" , linewidths = 2, marker = "s", edgecolor = "blue", s = 50 )
fig
ax[2].scatter(x,y,s =bubble_sizes, alpha=0.6, edgecolors='b', linewidths=2)

x1 = np.random.rand(50)
y1 = np.random.rand(50)

colors = np.random.rand(50)
sizes = 100*np.random.rand(50)

ax[3].scatter(x1,y1, s=sizes, c = colors, alpha=0.7, cmap='magma')

# %% [markdown]
# ## Sub-plot using Matplot interface

# %%
plt.figure() # create a plot figure

# create the first of two panels and set current axis
plt.subplot(2, 1, 1) # (rows, columns, panel number)
plt.plot(x, np.sin(x))

# create the second panel and set current axis
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x));

# %% [markdown]
# ## Sub-plot using Object Oriented interface

# %%
# First create a grid of plots
# ax will be an array of two Axes objects
fig, ax = plt.subplots(2)
# Call plot() method on the appropriate object
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x));

# %% [markdown]
# ## Simple line plots

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
fig = plt.figure()
ax = plt.axes()

# %%
fig = plt.figure()
ax = plt.axes()
x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x));

# %% [markdown]
# ## Line colors and styles

# %%
plt.plot(x, np.sin(x - 0), color='blue') # specify color by name
plt.plot(x, np.sin(x - 1), color='g') # short color code (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75') # Grayscale between 0 and 1
plt.plot(x, np.sin(x - 3), color='#FFDD44') # Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple, values 0 and 1
plt.plot(x, np.sin(x - 5), color='chartreuse'); # all HTML color names supported

# %%
#plt.plot(x, x + 0, linestyle='solid')
#plt.plot(x, x + 1, linestyle='dashed')
#plt.plot(x, x + 2, linestyle='dashdot')
#plt.plot(x, x + 3, linestyle='dotted');

# For short, you can use the following codes:
plt.plot(x, x + 4, linestyle='-') # solid
plt.plot(x, x + 5, linestyle='--') # dashed
plt.plot(x, x + 6, linestyle='-.') # dashdot
plt.plot(x, x + 7, linestyle=':'); # dotted

# %%
plt.plot(x, x + 0, '-g') # solid green
plt.plot(x, x + 1, '--c') # dashed cyan
plt.plot(x, x + 2, '-.k') # dashdot black
plt.plot(x, x + 3, ':r'); # dotted red

# %% [markdown]
# ## Axis Limit

# %%
plt.plot(x, np.sin(x))
plt.xlim(-1, 11)
plt.ylim(-1.5, 1.5);

# %%
plt.plot(x, np.sin(x))
plt.xlim(10, 0)
plt.ylim(1.2, -1.2);

# %% [markdown]
# ## Labelling plot

# %%
plt.plot(x, np.sin(x))
plt.title("A Sine Curve")
plt.xlabel("x")
plt.ylabel("sin(x)");

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.axis('equal')
plt.legend();

# %% [markdown]
# ## Scatter plot

# %%
x = np.linspace(0, 10, 30)
y = np.sin(x)
plt.plot(x, y, 'o', color='black');

# %%
rng = np.random.RandomState(0)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.rand(5), rng.rand(5), marker,label="marker='{0}'".format(marker))
plt.legend(numpoints=1)
plt.xlim(0, 1.8);

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)
plt.scatter(x, y, c=colors, s=sizes, alpha=0.3,
cmap='viridis')
plt.colorbar(); # show color scale

# %%
from sklearn.datasets import load_iris
iris = load_iris()
features = iris.data.T
plt.scatter(features[0], features[1], alpha=0.2,
s=100*features[3], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %%
def f(x, y):
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)
X, Y = np.meshgrid(x, y)
Z = f(X, Y)
plt.contour(X, Y, Z, colors='black');

# %%
plt.contour(X, Y, Z, 20, cmap='RdGy');

# %%
from random import sample
data=sample(range(1,1000),100)
plt.hist(data)
# Out:
# (array([ 8.,  8., 12., 11., 11., 11., 13.,  6.,  9., 11.]),
#  array([  3. , 100.9, 198.8, 296.7, 394.6, 492.5, 590.4, 688.3, 786.2,
#         884.1, 982. ]),
#  <BarContainer object of 10 artists>)

# %%
data=[np.random.normal(0,std,100) for std in range(1,4)]
plt.boxplot(data,vert=True,patch_artist=True);

# %%
plt.stairs(a)

# %%
plt.stem(a)
# Out:
# <StemContainer object of 3 artists>

# %%
plt.bar(x,y, width=1,edgecolor="white",linewidth=0.9)
# Out:
# <BarContainer object of 13 artists>

# %%
x=[1,2,3,4]
colors=plt.get_cmap('magma')(np.linspace(0.2,0.7,len(x)))

plt.pie(x,colors=colors,radius=5,center=(4,4),frame=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x18c30176820>,
#   <matplotlib.patches.Wedge at 0x18c30176d60>,
#   <matplotlib.patches.Wedge at 0x18c30185280>,
#   <matplotlib.patches.Wedge at 0x18c30185760>],
#  [Text(9.230810831666973, 5.699593493549404, ''),
#   Text(5.699593371113439, 9.230810871448828, ''),
#   Text(-1.230810951012531, 5.699593126241508, ''),
#   Text(5.699594105729209, -1.2308106327576542, '')])
